# %% [markdown]
# # Project 1 - Data Engineering
# ## 2 Data Exploration and Analysis
# This notebook is for the implementation of task "2 Data Exploration and Analysis", as listed in the **Project Instructions**.

# %% [markdown]
# <div class="alert alert-success">
# <b>Overview:</b><br>
# Data Exploration and Analysis consists of the following parts worth 70 points:
# <ul>
#     <li><b>E1 - Obtain and Scrub</b> (15 points)</li>
#     <li><b>E2 - Exploratory data analysis (EDA) </b>(20 points)</li>
#     <li><b>E3 - Formulate hypotheses </b>(25 points)</li>
#     <li><b>Follow the guidelines for Data Exploration and Analysis below </b>(10 points)</li>
# </ul></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Guidelines for Data Exploration and Analysis:</b><br>
#     <ol>
#         <li>Use a single Jupyer notebook for your project.</li>
#         <li>Use only Python-code for your project.</li>
#         <li>The use of automatic and semi-automatic data analyis tools is not allowed (e. g., PandasGUI, D-Tale, Mito, etc.). Only use packages we used in the coded lectures.</li>
#         <li>Export your environment for submission as 'prj01-environment.txt'.</li>
#         <li>Upload your resulting work as a zip file containing only a single jupyter notebook and required files to run the notebook. All cell outputs and <b>figures must display in jupyter lab</b>. (Test this, in particular when you use another environment like VS Code.)</li>
#         <li>All code cells in your notebook must be runnable without errors or warnings (e. g., deprecated functions). Each error/warning subtracts -2 points (up to the full 10 points for following the  guidelines).</li>
#         <li>Use only relative paths in your project.</li>
#         <li>Avoid (excessive) code duplication.</li>
#         <li>Avoid loops iterating over pandas objects (Series, DataFrames). Explicitly justify each exception via a comment. </li>
#         <li>All coded steps in your analysis must be commented.</li>
#         <li>Keep your code as well as outputs short, precise and readable. Each long or unnecessary output subtracts -2 points (up to the full 10 points for following the project guidelines).</li>
#     </ol>
#     <b>Late submissions are not accepted and earn you 0 points on the python project. </b>
# </div>

# %% [markdown]
# Explicitly list which notebook toolset was used (jupyter lab/jupyter notebook/VS Code/etc.)
#
# **here**: MY_TOOL, MY_BROWSER

# %% [markdown]
# Explicitly and clearly state the chosen dataset number and title:
# ### Health DG
# ## 99. Alzheimer's Disease and Healthy Aging Data

# %% [markdown]
# ## E1 - Obtain and Scrub

# %% [markdown]
# ### Obtain
# Download the dataset and understand both:
# - format: wide vs. long, separaters, decimal points, encoding, etc., and
# - content: what variables are in the columns, what is their meaning?
# To this end, identify and download metadata such as headers, category listings, explanatory reports, etc.
# ### Scrub
# The aim of scrub is to create a clean version of the data for further analysis.
# - Load the dataset and take care of dtypes (dates, numbers, categories, etc.). Justify why you don't load/use specific columns.
# - Check for footnotes or any other notifications on special cell content, such as time series breaks. Follow up that information, and document your decision how to deal with it. Remember: The homework 4 contained such info in the cell "76.1 b". The metadata defines what that "b" stands for.
# ![image.png](attachment:8eab5647-0d31-4875-a3ac-990349e90b76.png)
# - Choose an appropriate (Multi-)Index.
# - Identify:
#     1. missing values and get row and column overviews. Use graphical and/or numeric approaches. Once identified, handle missing values according to column type, time series property and data set size.
#     2. duplicates (justify the used column subset). Remove duplicates - if any - and inspect what you removed.
# - Transform to shape (tidy vs. wide) best suited for further analysis.
# - Export the clean data to a file for inspection with an external data browser (e.g., MS Excel).
# - Provide an overview of the clean dataset:
#     1. show the dtypes
#     2. quantitative column descriptions:
#         1. categorical columns: number of unique values, counts
#         2. numeric columns: range and median

# %%
# E1:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

file_path = 'Alzheimer_s_Disease_and_Healthy_Aging_Data.csv'
data = pd.read_csv(file_path)

data_info = data.info()
data_description = data.describe(include='all')
missing_values = data.isnull().sum()
# Out:
# C:\Users\sbart\AppData\Local\Temp\ipykernel_19884\1987952276.py:12: DtypeWarning: Columns (17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250937 entries, 0 to 250936
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   RowId                       250937 non-null  object
#  1   YearStart                   250937 non-null  int64
#  2   YearEnd                     250937 non-null  int64
#  3   LocationAbbr                250937 non-null  object
#  4   LocationDesc                250937 non-null  object
#  5   Datasource                  250937 non-null  object
#  6   Class                       250937 non-null  object
#  7   Topic                       250937 non-null  object
#  8   Question                    250937 non-null  object
#  9   Response                    0 non-null       float64
#  10  Data_Value_Unit             250937 non-null  object
#  11  DataValueTypeID             250937 non-null  object
#  12  Data_Value_Type             250937 non-null  object
#  13  Data_Value                  169302 non-null  float64
#  14  Data_Value_Alt              169302 non-null  float64
#  15  Data_Value_Footnote_Symbol  99114 non-null   object
#  16  Data_Value_Footnote         99114 non-null   object
#  17  Low_Confidence_Limit        169152 non-null  object
#  18  High_Confidence_Limit       169152 non-null  object
#  19  Sample_Size                 0 non-null       float64
#  20  StratificationCategory1     250937 non-null  object
#  21  Stratification1             250937 non-null  object
#  22  StratificationCategory2     218561 non-null  object
#  23  Stratification2             218561 non-null  object
#  24  StratificationCategory3     0 non-null       float64
#  25  Stratification3             0 non-null       float64
#  26  Geolocation                 224228 non-null  object
#  27  ClassID                     250937 non-null  object
#  28  TopicID                     250937 non-null  object
#  29  QuestionID                  250937 non-null  object
#  30  ResponseID                  0 non-null       float64
#  31  LocationID                  250937 non-null  int64
#  32  StratificationCategoryID1   250937 non-null  object
#  33  StratificationID1           250937 non-null  object
#  34  StratificationCategoryID2   250937 non-null  object
#  35  StratificationID2           250937 non-null  object
#  36  StratificationCategoryID3   0 non-null       float64
#  37  StratificationID3           0 non-null       float64
#  38  Report                      0 non-null       float64
# dtypes: float64(10), int64(3), object(26)
# memory usage: 74.7+ MB

# %%
columns_to_drop = ['Response', 'Sample_Size', 'StratificationCategory3', 'Stratification3', 'StratificationCategoryID3',
                   'StratificationID3','ResponseID', 'Report', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'Geolocation']
data_cleaned = data.drop(columns=columns_to_drop)

# Converting 'Low_Confidence_Limit' and 'High_Confidence_Limit' to numeric (if possible)
data_cleaned['Low_Confidence_Limit'] = pd.to_numeric(data_cleaned['Low_Confidence_Limit'], errors='coerce')
data_cleaned['High_Confidence_Limit'] = pd.to_numeric(data_cleaned['High_Confidence_Limit'], errors='coerce')

# Handling missing values in numerical columns by imputing with the median
# numerical_columns = data_cleaned.select_dtypes(include=['float64', 'int64']).columns
#data_cleaned[numerical_columns] = data_cleaned[numerical_columns].apply(lambda x: x.fillna(x.median()),axis=0)

# Extracting latitude and longitude from the 'Geolocation' column
# data_cleaned['Geolocation'] = data_cleaned['Geolocation'].str.extract(r'POINT \(([^)]+)\)')
# data_cleaned[['Latitude', 'Longitude']] = data_cleaned['Geolocation'].str.split(" ", expand=True)

# # Converting the extracted values to numeric
# data_cleaned['Latitude'] = pd.to_numeric(data_cleaned['Latitude'], errors='coerce')
# data_cleaned['Longitude'] = pd.to_numeric(data_cleaned['Longitude'], errors='coerce')

string_cols = data_cleaned.select_dtypes(include=['object']).columns
for col in string_cols:
    data_cleaned[col] = data_cleaned[col].astype(str).str.strip()

data_cleaned.head(100)
# Out:
#                                          RowId  YearStart  YearEnd  \
# 0      BRFSS~2021~2021~9004~Q43~TOC11~AGE~RACE       2021     2021
# 1   BRFSS~2017~2017~9001~Q43~TOC11~AGE~OVERALL       2017     2017
# 2   BRFSS~2019~2019~9002~Q02~TNC02~AGE~OVERALL       2019     2019
# 3      BRFSS~2020~2020~59~Q43~TOC11~AGE~GENDER       2020     2020
# 4      BRFSS~2020~2020~33~Q03~TMC01~AGE~GENDER       2020     2020
# 5      BRFSS~2015~2015~9002~Q43~TOC11~AGE~RACE       2015     2015
# 6      BRFSS~2020~2020~59~Q35~TOC03~AGE~GENDER       2020     2020
# 7   BRFSS~2021~2021~9001~Q18~TSC08~AGE~OVERALL       2021     2021
# 8      BRFSS~2021~2021~17~Q08~TOC01~AGE~GENDER       2021     2021
# 9     BRFSS~2020~2020~50~Q34~TOC09~AGE~OVERALL       2020     2020
# 10    BRFSS~2016~2016~09~Q35~TOC03~AGE~OVERALL       2016     2016
# 11     BRFSS~2021~2021~49~Q43~TOC11~AGE~GENDER       2021     2021
# 12    BRFSS~2020~2020~32~Q43~TOC11~AGE~OVERALL       2020     2020
# 13    BRFSS~2020~2020~50~Q27~TMC03~AGE~OVERALL       2020     2020
# 14    BRFSS~2021~2021~06~Q43~TOC11~AGE~OVERALL       2021     2021
# 15     BRFSS~2021~2021~18~Q03~TMC01~AGE~GENDER       2021     2021
# 16     BRFSS~2020~2020~9003~Q27~TMC03~AGE~RACE       2020     2020
# 17     BRFSS~2020~2020~72~Q43~TOC11~AGE~GENDER       2020     2020
# 18    BRFSS~2017~2017~16~Q43~TOC11~AGE~OVERALL       2017     2017
# 19       BRFSS~2021~2021~53~Q43~TOC11~AGE~RACE       2021     2021
# 20     BRFSS~2020~2020~39~Q43~TOC11~AGE~GENDER       2020     2020
# 21       BRFSS~2020~2020~56~Q43~TOC11~AGE~RACE       2020     2020
# 22     BRFSS~2015~2015~66~Q43~TOC11~AGE~GENDER       2015     2015
# 23     BRFSS~2015~2015~9002~Q43~TOC11~AGE~RACE       2015     2015
# 24    BRFSS~2016~2016~12~Q27~TMC03~AGE~OVERALL       2016     2016
# 25     BRFSS~2015~2015~16~Q27~TMC03~AGE~GENDER       2015     2015
# 96     BRFSS~2017~2017~16~Q43~TOC11~AGE~GENDER       2017     2017
# 97     BRFSS~2020~2020~9001~Q43~TOC11~AGE~RACE       2020     2020
# 98  BRFSS~2020~2020~9001~Q21~TAC03~AGE~OVERALL       2020     2020
# 99     BRFSS~2020~2020~48~Q27~TMC03~AGE~GENDER       2020     2020
#
#    LocationAbbr                     LocationDesc Datasource  \
# 0          WEST                             West      BRFSS
# 1           NRE                        Northeast      BRFSS
# 2           MDW                          Midwest      BRFSS
# 3            US  United States, DC & Territories      BRFSS
# 4            NH                    New Hampshire      BRFSS
# 5           MDW                          Midwest      BRFSS
# 6            US  United States, DC & Territories      BRFSS
# 7           NRE                        Northeast      BRFSS
# 8            IL                         Illinois      BRFSS
# 9            VT                          Vermont      BRFSS
# 10           CT                      Connecticut      BRFSS
# 11           UT                             Utah      BRFSS
# 12           NV                           Nevada      BRFSS
# 13           VT                          Vermont      BRFSS
# 14           CA                       California      BRFSS
# 15           IN                          Indiana      BRFSS
# 16          SOU                            South      BRFSS
# 17           PR                      Puerto Rico      BRFSS
# 18           ID                            Idaho      BRFSS
# 19           WA                       Washington      BRFSS
# 20           OH                             Ohio      BRFSS
# 21           WY                          Wyoming      BRFSS
# 22           GU                             Guam      BRFSS
# 23          MDW                          Midwest      BRFSS
# 24           FL                          Florida      BRFSS
# 25           ID                            Idaho      BRFSS
# 26           IN                          Indiana      BRFSS
# 27           ME                            Maine      BRFSS
# 28           DE                         Delaware      BRFSS
# 29           MI                         Michigan      BRFSS
# 30           CO                         Colorado      BRFSS
# 31          MDW                          Midwest      BRFSS
# 32         WEST                             West      BRFSS
# 33           GU                             Guam      BRFSS
# 34         WEST                             West      BRFSS
# 35           GU                             Guam      BRFSS
# 36         WEST                             West      BRFSS
# 37           MO                         Missouri      BRFSS
# 38           KS                           Kansas      BRFSS
# 39           MD                         Maryland      BRFSS
# 40           WI                        Wisconsin      BRFSS
# 41         WEST                             West      BRFSS
# 42           FL                          Florida      BRFSS
# 43           IA                             Iowa      BRFSS
# 44           IA                             Iowa      BRFSS
# 45           CO                         Colorado      BRFSS
# 46           TX                            Texas      BRFSS
# 47           KS                           Kansas      BRFSS
# 48           DE                         Delaware      BRFSS
# 49           VA                         Virginia      BRFSS
# 50           KS                           Kansas      BRFSS
# 51          MDW                          Midwest      BRFSS
# 52           IA                             Iowa      BRFSS
# 53           GU                             Guam      BRFSS
# 54           MS                      Mississippi      BRFSS
# 55           IA                             Iowa      BRFSS
# 56           KY                         Kentucky      BRFSS
# 57           LA                        Louisiana      BRFSS
# 58           VT                          Vermont      BRFSS
# 59          NRE                        Northeast      BRFSS
# 60          NRE                        Northeast      BRFSS
# 61         WEST                             West      BRFSS
# 62         WEST                             West      BRFSS
# 63           NV                           Nevada      BRFSS
# 64           ID                            Idaho      BRFSS
# 65           AK                           Alaska      BRFSS
# 66           WA                       Washington      BRFSS
# 67           NJ                       New Jersey      BRFSS
# 68           MO                         Missouri      BRFSS
# 69          SOU                            South      BRFSS
# 70           IN                          Indiana      BRFSS
# 71           WY                          Wyoming      BRFSS
# 72           TX                            Texas      BRFSS
# 73           AZ                          Arizona      BRFSS
# 74          NRE                        Northeast      BRFSS
# 75          SOU                            South      BRFSS
# 76           WA                       Washington      BRFSS
# 77           GU                             Guam      BRFSS
# 78         WEST                             West      BRFSS
# 79           GU                             Guam      BRFSS
# 80         WEST                             West      BRFSS
# 81           IL                         Illinois      BRFSS
# 82           AZ                          Arizona      BRFSS
# 83           RI                     Rhode Island      BRFSS
# 84         WEST                             West      BRFSS
# 85           AL                          Alabama      BRFSS
# 86           IN                          Indiana      BRFSS
# 87           US  United States, DC & Territories      BRFSS
# 88           ID                            Idaho      BRFSS
# 89           IA                             Iowa      BRFSS
# 90           KY                         Kentucky      BRFSS
# 91           ME                            Maine      BRFSS
# 92           MN                        Minnesota      BRFSS
# 93           WY                          Wyoming      BRFSS
# 94          SOU                            South      BRFSS
# 95         WEST                             West      BRFSS
# 96           ID                            Idaho      BRFSS
# 97          NRE                        Northeast      BRFSS
# 98          NRE                        Northeast      BRFSS
# 99           TX                            Texas      BRFSS
#
#                                   Class  \
# 0                        Overall Health
# 1                        Overall Health
# 2   Nutrition/Physical Activity/Obesity
# 3                        Overall Health
# 4                         Mental Health
# 5                        Overall Health
# 6                        Overall Health
# 7               Screenings and Vaccines
# 8                        Overall Health
# 9                        Overall Health
# 10                       Overall Health
# 11                       Overall Health
# 12                       Overall Health
# 13                        Mental Health
# 14                       Overall Health
# 15                        Mental Health
# 16                        Mental Health
# 17                       Overall Health
# 18                       Overall Health
# 19                       Overall Health
# 20                       Overall Health
# 21                       Overall Health
# 22                       Overall Health
# 23                       Overall Health
# 24                        Mental Health
# 25                        Mental Health
# 26                       Overall Health
# 27                        Mental Health
# 28                        Mental Health
# 29                        Mental Health
# 30                        Mental Health
# 31                        Mental Health
# 32                       Overall Health
# 33                       Overall Health
# 34                       Overall Health
# 35                       Overall Health
# 36                        Mental Health
# 37                       Overall Health
# 38                       Overall Health
# 39  Nutrition/Physical Activity/Obesity
# 40                       Overall Health
# 41  Nutrition/Physical Activity/Obesity
# 42                        Mental Health
# 43                       Overall Health
# 44                        Mental Health
# 45                       Overall Health
# 46                       Overall Health
# 47                        Mental Health
# 48                        Mental Health
# 49                        Mental Health
# 50                        Mental Health
# 51                       Overall Health
# 52                       Overall Health
# 53                        Mental Health
# 54                       Overall Health
# 55                       Overall Health
# 56                       Overall Health
# 57                        Mental Health
# 58                       Overall Health
# 59              Screenings and Vaccines
# 60                       Overall Health
# 61              Screenings and Vaccines
# 62                       Overall Health
# 63                       Overall Health
# 64                        Mental Health
# 65                        Mental Health
# 66                       Overall Health
# 67                       Overall Health
# 68                       Overall Health
# 69                       Overall Health
# 70                        Mental Health
# 71                        Mental Health
# 72                       Overall Health
# 73                        Mental Health
# 74                       Overall Health
# 75                        Mental Health
# 76                       Overall Health
# 77                       Overall Health
# 78                       Overall Health
# 79                       Overall Health
#    Data_Value_Unit DataValueTypeID Data_Value_Type  Data_Value  \
# 0                %           PRCTG      Percentage        31.6
# 1                %           PRCTG      Percentage        50.3
# 2                %           PRCTG      Percentage        14.3
# 3                %           PRCTG      Percentage        55.5
# 4                %           PRCTG      Percentage        15.2
# 5                %           PRCTG      Percentage        59.8
# 6           Number            MEAN            Mean         6.2
# 7                %           PRCTG      Percentage        61.0
# 8           Number            MEAN            Mean         3.6
# 9                %           PRCTG      Percentage        69.1
# 10          Number            MEAN            Mean         6.2
# 11               %           PRCTG      Percentage        35.6
# 12               %           PRCTG      Percentage        33.9
# 13               %           PRCTG      Percentage        19.9
# 14               %           PRCTG      Percentage        36.1
# 15               %           PRCTG      Percentage         8.5
# 16               %           PRCTG      Percentage        14.1
# 17               %           PRCTG      Percentage        33.8
# 18               %           PRCTG      Percentage        42.0
# 19               %           PRCTG      Percentage        28.0
# 20               %           PRCTG      Percentage        40.6
# 21               %           PRCTG      Percentage        40.3
# 22               %           PRCTG      Percentage        28.4
# 23               %           PRCTG      Percentage        44.1
# 24               %           PRCTG      Percentage        17.7
# 25               %           PRCTG      Percentage        16.0
# 26               %           PRCTG      Percentage        45.7
# 27               %           PRCTG      Percentage        30.1
# 28               %           PRCTG      Percentage        12.4
# 29               %           PRCTG      Percentage        15.4
# 30               %           PRCTG      Percentage        11.3
# 31               %           PRCTG      Percentage        18.3
# 32          Number            MEAN            Mean         5.8
# 33               %           PRCTG      Percentage        24.8
# 34          Number            MEAN            Mean         4.3
# 35               %           PRCTG      Percentage        28.9
# 36               %           PRCTG      Percentage         8.2
# 37               %           PRCTG      Percentage        73.6
# 38               %           PRCTG      Percentage        67.8
# 39               %           PRCTG      Percentage        38.0
# 40               %           PRCTG      Percentage        33.4
# 41               %           PRCTG      Percentage        34.2
# 42               %           PRCTG      Percentage        12.6
# 43               %           PRCTG      Percentage        52.3
# 44               %           PRCTG      Percentage        11.3
# 45               %           PRCTG      Percentage        29.1
# 46               %           PRCTG      Percentage        66.2
# 47               %           PRCTG      Percentage        11.0
# 48               %           PRCTG      Percentage        18.5
# 49               %           PRCTG      Percentage        10.7
# 50               %           PRCTG      Percentage         7.9
# 51          Number            MEAN            Mean         6.5
# 52               %           PRCTG      Percentage        76.8
# 53               %           PRCTG      Percentage        11.0
# 54               %           PRCTG      Percentage        55.0
# 55               %           PRCTG      Percentage        80.2
# 56               %           PRCTG      Percentage        50.4
# 57               %           PRCTG      Percentage        13.4
# 58               %           PRCTG      Percentage        45.7
# 59               %           PRCTG      Percentage        50.9
# 60               %           PRCTG      Percentage        31.7
# 61               %           PRCTG      Percentage        52.1
# 62          Number            MEAN            Mean         6.3
# 63          Number            MEAN            Mean         6.6
# 64               %           PRCTG      Percentage         9.5
# 65               %           PRCTG      Percentage        18.1
# 66               %           PRCTG      Percentage        35.2
# 67               %           PRCTG      Percentage        29.5
# 68               %           PRCTG      Percentage        37.9
# 69               %           PRCTG      Percentage        43.1
# 70               %           PRCTG      Percentage        14.5
# 71               %           PRCTG      Percentage         9.9
# 72          Number            MEAN            Mean         6.9
# 73               %           PRCTG      Percentage        10.7
# 74          Number            MEAN            Mean         6.3
# 75               %           PRCTG      Percentage        15.0
# 76               %           PRCTG      Percentage        73.3
# 77               %           PRCTG      Percentage        40.9
# 78               %           PRCTG      Percentage        67.3
# 79          Number            MEAN            Mean         7.2
# 80               %           PRCTG      Percentage        23.0
# 81               %           PRCTG      Percentage        36.5
# 82               %           PRCTG      Percentage        71.8
# 83          Number            MEAN            Mean         6.1
# 84          Number            MEAN            Mean         6.3
# 85               %           PRCTG      Percentage        46.1
# 86               %           PRCTG      Percentage        51.0
# 87               %           PRCTG      Percentage        65.4
# 88          Number            MEAN            Mean         6.7
# 89               %           PRCTG      Percentage        70.2
# 90               %           PRCTG      Percentage        41.6
# 91          Number            MEAN            Mean         4.9
# 92               %           PRCTG      Percentage         7.0
# 93               %           PRCTG      Percentage        10.0
# 94               %           PRCTG      Percentage        42.8
# 95          Number            MEAN            Mean         4.1
# 96               %           PRCTG      Percentage        47.0
# 97               %           PRCTG      Percentage        36.5
# 98               %           PRCTG      Percentage        13.5
# 99               %           PRCTG      Percentage        21.0
#
#     Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit  \
# 0             31.6                  28.8                   34.4
# 1             50.3                  49.1                   51.6
# 2             14.3                  13.8                   14.8
# 3             55.5                  54.5                   56.4
# 4             15.2                  12.8                   18.0
# 5             59.8                  48.4                   70.2
# 6              6.2                   5.8                    6.5
# 7             61.0                  60.2                   61.8
# 8              3.6                   2.6                    4.6
# 9             69.1                  66.4                   71.6
# 10             6.2                   5.6                    6.8
# 11            35.6                  32.3                   39.0
# 12            33.9                  28.7                   39.4
# 13            19.9                  18.4                   21.5
# 14            36.1                  33.8                   38.4
# 15             8.5                   7.0                   10.2
# 16            14.1                   8.6                   22.2
# 17            33.8                  26.4                   42.1
# 18            42.0                  39.7                   44.3
# 19            28.0                  22.8                   33.8
# 20            40.6                  37.8                   43.5
# 21            40.3                  26.2                   56.1
# 22            28.4                  20.5                   37.8
# 23            44.1                  41.2                   47.0
# 24            17.7                  16.2                   19.4
# 25            16.0                  12.7                   19.9
# 26            45.7                  43.7                   47.8
# 27            30.1                  27.3                   33.1
# 28            12.4                  10.3                   14.8
# 29            15.4                  12.9                   18.2
# 30            11.3                  10.1                   12.8
# 31            18.3                  12.6                   26.0
# 32             5.8                   5.3                    6.3
# 33            24.8                  15.3                   37.6
# 34             4.3                   3.8                    4.9
# 35            28.9                  23.7                   34.8
# 36             8.2                   7.0                    9.5
# 37            73.6                  70.8                   76.3
# 38            67.8                  65.3                   70.2
# 39            38.0                  36.0                   40.1
# 40            33.4                  30.2                   36.8
# 41            34.2                  31.3                   37.2
# 42            12.6                  11.0                   14.3
# 43            52.3                  49.7                   54.8
# 44            11.3                  10.0                   12.8
# 45            29.1                  26.3                   32.1
# 46            66.2                  61.4                   70.8
# 47            11.0                   9.6                   12.6
# 48            18.5                  16.2                   21.1
# 49            10.7                   9.5                   11.9
# 50             7.9                   6.7                    9.4
# 51             6.5                   5.9                    7.1
# 52            76.8                  74.2                   79.1
# 53            11.0                   6.7                   17.7
# 54            55.0                  52.5                   57.5
# 55            80.2                  78.4                   82.0
# 56            50.4                  48.3                   52.4
# 57            13.4                  10.1                   17.5
# 58            45.7                  43.6                   47.8
# 59            50.9                  49.2                   52.5
# 60            31.7                  30.5                   32.9
# 61            52.1                  49.5                   54.7
# 62             6.3                   5.7                    6.8
# 63             6.6                   4.8                    8.3
# 64             9.5                   7.7                   11.7
# 65            18.1                  14.9                   21.8
# 66            35.2                  33.2                   37.3
# 67            29.5                  26.9                   32.3
# 68            37.9                  34.1                   42.0
# 69            43.1                  42.3                   43.8
# 70            14.5                  12.8                   16.3
# 71             9.9                   7.2                   13.5
# 72             6.9                   5.2                    8.6
# 73            10.7                   9.5                   12.1
# 74             6.3                   5.9                    6.6
# 75            15.0                  14.3                   15.7
# 76            73.3                  71.5                   75.1
# 77            40.9                  31.8                   50.7
# 78            67.3                  65.2                   69.4
# 79             7.2                   5.0                    9.4
# 80            23.0                  21.1                   24.9
# 81            36.5                  33.4                   39.7
# 82            71.8                  68.9                   74.5
# 83             6.1                   5.3                    6.8
# 84             6.3                   5.3                    7.3
# 85            46.1                  43.4                   48.8
# 86            51.0                  41.0                   60.9
# 87            65.4                  64.4                   66.4
# 88             6.7                   5.6                    7.7
# 89            70.2                  67.2                   73.1
# 90            41.6                  38.2                   45.0
# 91             4.9                   4.4                    5.3
# 92             7.0                   6.4                    7.6
# 93            10.0                   7.3                   13.5
# 94            42.8                  36.5                   49.3
# 95             4.1                   3.5                    4.8
# 96            47.0                  43.8                   50.2
# 97            36.5                  33.4                   39.7
# 98            13.5                  12.7                   14.4
# 99            21.0                  18.3                   24.0
#
#    StratificationCategory1    Stratification1 StratificationCategory2  \
# 0                Age Group            Overall          Race/Ethnicity
# 1                Age Group  65 years or older                     nan
# 2                Age Group            Overall                     nan
# 3                Age Group  65 years or older                  Gender
# 4                Age Group        50-64 years                  Gender
# 5                Age Group  65 years or older          Race/Ethnicity
# 6                Age Group  65 years or older                  Gender
# 7                Age Group            Overall                     nan
# 8                Age Group        50-64 years                  Gender
# 9                Age Group        50-64 years                     nan
# 10               Age Group        50-64 years                     nan
# ...
# 16    Asian/Pacific Islander     C05   TMC03        Q27        9003
# 17                      Male     C01   TOC11        Q43          72
# 18                       nan     C01   TOC11        Q43          16
# 19                  Hispanic     C01   TOC11        Q43          53
# 20                    Female     C01   TOC11        Q43          39
# 21                  Hispanic     C01   TOC11        Q43          56
# 22                    Female     C01   TOC11        Q43          66
# 23       Black, non-Hispanic     C01   TOC11        Q43        9002
# 24                       nan     C05   TMC03        Q27          12
# 25                      Male     C05   TMC03        Q27          16
# 26                       nan     C01   TOC11        Q43          18
# 27                    Female     C05   TMC03        Q27          23
# 28                    Female     C05   TMC01        Q03          10
# 29                      Male     C05   TMC03        Q27          26
# 30                       nan     C05   TMC01        Q03           8
# 31  Native Am/Alaskan Native     C05   TMC01        Q03        9002
# 32       White, non-Hispanic     C01   TOC03        Q35        9004
# 33                    Female     C01   TOC11        Q43          66
# 34                    Female     C01   TOC01        Q08        9004
# 35    Asian/Pacific Islander     C01   TOC11        Q43          66
# 36       White, non-Hispanic     C05   TMC01        Q03        9004
# 37                    Female     C01   TOC09        Q34          29
# 38                    Female     C01   TOC09        Q34          20
# 39                       nan     C02   TNC01        Q01          24
# 40                       nan     C01   TOC11        Q43          55
# 41                      Male     C02   TNC04        Q13        9004
# 42                       nan     C05   TMC03        Q27          12
# 43                       nan     C01   TOC11        Q43          19
# 44                       nan     C05   TMC01        Q03          19
# 45                      Male     C01   TOC11        Q43           8
# 46                      Male     C01   TOC09        Q34          48
# 47                      Male     C05   TMC03        Q27          20
# 48                       nan     C05   TMC03        Q27          10
# 49                       nan     C05   TMC01        Q03          51
# 50                      Male     C05   TMC01        Q03          20
# 51                      Male     C01   TOC03        Q35        9002
# 52                    Female     C01   TOC09        Q34          19
# 53                    Female     C05   TMC03        Q27          66
# 54                       nan     C01   TOC11        Q43          28
# 55                       nan     C01   TOC09        Q34          19
# 56                       nan     C01   TOC11        Q43          21
# 57                      Male     C05   TMC01        Q03          22
# 58       White, non-Hispanic     C01   TOC11        Q43          50
# 59                      Male     C03   TSC08        Q18        9001
# 60       White, non-Hispanic     C01   TOC11        Q43        9001
# 61                    Female     C03   TSC08        Q18        9004
# 62                       nan     C01   TOC03        Q35        9004
# 63                      Male     C01   TOC03        Q35          32
# 64                      Male     C05   TMC03        Q27          16
# 65                       nan     C05   TMC03        Q27           2
# 66                       nan     C01   TOC11        Q43          53
# 67                    Female     C01   TOC11        Q43          34
# 68                      Male     C01   TOC11        Q43          29
# 69                       nan     C01   TOC11        Q43        9003
# 70                       nan     C05   TMC01        Q03          18
# 71                      Male     C05   TMC03        Q27          56
# 72                      Male     C01   TOC03        Q35          48
# 73                       nan     C05   TMC01        Q03           4
# 74                      Male     C01   TOC03        Q35        9001
# 75                       nan     C05   TMC03        Q27        9003
# 76                    Female     C01   TOC09        Q34          53
# 77                       nan     C01   TOC11        Q43          66
# 78                       nan     C01   TOC09        Q34        9004
# 79                       nan     C01   TOC03        Q35          66
# 80                    Female     C05   TMC03        Q27        9004
# 81                      Male     C01   TOC11        Q43          17
# 82                    Female     C01   TOC09        Q34           4
# 83                       nan     C01   TOC03        Q35          44
# 84                      Male     C01   TOC03        Q35        9004
# 85                       nan     C01   TOC11        Q43           1
# 86       Black, non-Hispanic     C01   TOC11        Q43          18
# 87                      Male     C01   TOC09        Q34          59
# 88                      Male     C01   TOC03        Q35          16
# 89                    Female     C01   TOC09        Q34          19
# 90                      Male     C01   TOC11        Q43          21
# 91                       nan     C01   TOC01        Q08          23
# 92                       nan     C05   TMC01        Q03          27
# 93                      Male     C05   TMC03        Q27          56
# 94                  Hispanic     C01   TOC11        Q43        9003
# 95                      Male     C01   TOC01        Q08        9004
# 96                    Female     C01   TOC11        Q43          16
# 97                  Hispanic     C01   TOC11        Q43        9001
# 98                       nan     C04   TAC03        Q21        9001
# 99                    Female     C05   TMC03        Q27          48
#
#    StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 0                        AGE       AGE_OVERALL                      RACE
# 1                        AGE            65PLUS                   OVERALL
# 2                        AGE       AGE_OVERALL                   OVERALL
# 3                        AGE            65PLUS                    GENDER
# 4                        AGE              5064                    GENDER
# 5                        AGE            65PLUS                      RACE
# 6                        AGE            65PLUS                    GENDER
# 7                        AGE       AGE_OVERALL                   OVERALL
# 8                        AGE              5064                    GENDER
# 9                        AGE              5064                   OVERALL
# 10                       AGE              5064                   OVERALL
# 11                       AGE              5064                    GENDER
# 12                       AGE              5064                   OVERALL
# 13                       AGE       AGE_OVERALL                   OVERALL
# 14                       AGE       AGE_OVERALL                   OVERALL
# 15                       AGE            65PLUS                    GENDER
# 16                       AGE              5064                      RACE
# 17                       AGE            65PLUS                    GENDER
# 18                       AGE       AGE_OVERALL                   OVERALL
# 19                       AGE       AGE_OVERALL                      RACE
# 20                       AGE              5064                    GENDER
# 21                       AGE              5064                      RACE
# 22                       AGE              5064                    GENDER
# 23                       AGE       AGE_OVERALL                      RACE
# 24                       AGE              5064                   OVERALL
# 25                       AGE              5064                    GENDER
# 26                       AGE       AGE_OVERALL                   OVERALL
# 27                       AGE              5064                    GENDER
# 28                       AGE       AGE_OVERALL                    GENDER
# 29                       AGE              5064                    GENDER
# 30                       AGE              5064                   OVERALL
# 31                       AGE              5064                      RACE
# 32                       AGE              5064                      RACE
# 33                       AGE              5064                    GENDER
# 34                       AGE              5064                    GENDER
# 35                       AGE       AGE_OVERALL                      RACE
# 36                       AGE            65PLUS                      RACE
# 37                       AGE            65PLUS                    GENDER
# 38                       AGE              5064                    GENDER
# 39                       AGE              5064                   OVERALL
# 40                       AGE              5064                   OVERALL
# 41                       AGE              5064                    GENDER
# 42                       AGE            65PLUS                   OVERALL
# 43                       AGE            65PLUS                   OVERALL
# 44                       AGE              5064                   OVERALL
# 45                       AGE              5064                    GENDER
# 46                       AGE              5064                    GENDER
# 47                       AGE       AGE_OVERALL                    GENDER
# 48                       AGE              5064                   OVERALL
# 49                       AGE       AGE_OVERALL                   OVERALL
# 50                       AGE       AGE_OVERALL                    GENDER
# 51                       AGE              5064                    GENDER
# 52                       AGE            65PLUS                    GENDER
# 53                       AGE              5064                    GENDER
# 54                       AGE            65PLUS                   OVERALL
# 55                       AGE            65PLUS                   OVERALL
# 56                       AGE       AGE_OVERALL                   OVERALL
# 57                       AGE              5064                    GENDER
# 58                       AGE       AGE_OVERALL                      RACE
# 59                       AGE              5064                    GENDER
# 60                       AGE              5064                      RACE
# 61                       AGE              5064                    GENDER
# 62                       AGE       AGE_OVERALL                   OVERALL
# 63                       AGE       AGE_OVERALL                    GENDER
# 64                       AGE       AGE_OVERALL                    GENDER
# 65                       AGE              5064                   OVERALL
# 66                       AGE              5064                   OVERALL
# 67                       AGE              5064                    GENDER
# 68                       AGE              5064                    GENDER
# 69                       AGE       AGE_OVERALL                   OVERALL
# 70                       AGE              5064                   OVERALL
# 71                       AGE              5064                    GENDER
# 72                       AGE              5064                    GENDER
# 73                       AGE       AGE_OVERALL                   OVERALL
# 74                       AGE       AGE_OVERALL                    GENDER
# 75                       AGE            65PLUS                   OVERALL
# 76                       AGE       AGE_OVERALL                    GENDER
# 77                       AGE            65PLUS                   OVERALL
# 78                       AGE              5064                   OVERALL
# 79                       AGE       AGE_OVERALL                   OVERALL
# 80                       AGE              5064                    GENDER
# 81                       AGE       AGE_OVERALL                    GENDER
# 82                       AGE       AGE_OVERALL                    GENDER
# 83                       AGE       AGE_OVERALL                   OVERALL
# 84                       AGE              5064                    GENDER
# 85                       AGE              5064                   OVERALL
# 86                       AGE            65PLUS                      RACE
# 87                       AGE              5064                    GENDER
# 88                       AGE       AGE_OVERALL                    GENDER
# 89                       AGE              5064                    GENDER
# 90                       AGE       AGE_OVERALL                    GENDER
# 91                       AGE            65PLUS                   OVERALL
# 92                       AGE       AGE_OVERALL                   OVERALL
# 93                       AGE            65PLUS                    GENDER
# 94                       AGE            65PLUS                      RACE
# 95                       AGE            65PLUS                    GENDER
# 96                       AGE       AGE_OVERALL                    GENDER
# 97                       AGE       AGE_OVERALL                      RACE
# 98                       AGE              5064                   OVERALL
# 99                       AGE       AGE_OVERALL                    GENDER
#
#    StratificationID2
# 0                HIS
# 1            OVERALL
# 2            OVERALL
# 3             FEMALE
# 4             FEMALE
# 5                NAA
# 6               MALE
# 7            OVERALL
# 8               MALE
# 9            OVERALL
# 10           OVERALL
# 11            FEMALE
# 12           OVERALL
# 13           OVERALL
# 14           OVERALL
# 15            FEMALE
# 16               ASN
# 17              MALE
# 18           OVERALL
# 19               HIS
# 20            FEMALE
# 21               HIS
# 22            FEMALE
# 23               BLK
# 24           OVERALL
# 25              MALE
# 26           OVERALL
# 27            FEMALE
# 28            FEMALE
# 29              MALE
# 30           OVERALL
# 31               NAA
# 32               WHT
# 33            FEMALE
# 34            FEMALE
# 35               ASN
# 36               WHT
# 37            FEMALE
# 38            FEMALE
# 39           OVERALL
# 40           OVERALL
# 41              MALE
# 42           OVERALL
# 43           OVERALL
# 44           OVERALL
# 45              MALE
# 46              MALE
# 47              MALE
# 48           OVERALL
# 49           OVERALL
# 50              MALE
# 51              MALE
# 52            FEMALE
# 53            FEMALE
# 54           OVERALL
# 55           OVERALL
# 56           OVERALL
# 57              MALE
# 58               WHT
# 59              MALE
# 60               WHT
# 61            FEMALE
# 62           OVERALL
# 63              MALE
# 64              MALE
# 65           OVERALL
# 66           OVERALL
# 67            FEMALE
# 68              MALE
# 69           OVERALL
# 70           OVERALL
# 71              MALE
# 72              MALE
# 73           OVERALL
# 74              MALE
# 75           OVERALL
# 76            FEMALE
# 77           OVERALL
# 78           OVERALL
# 79           OVERALL
# 80            FEMALE
# 81              MALE
# 82            FEMALE
# 83           OVERALL
# 84              MALE
# 85           OVERALL
# 86               BLK
# 87              MALE
# 88              MALE
# 89            FEMALE
# 90              MALE
# 91           OVERALL
# 92           OVERALL
# 93              MALE
# 94               HIS
# 95              MALE
# 96            FEMALE
# 97               HIS
# 98           OVERALL
# 99            FEMALE

# %%
mental_distress_data= data_cleaned[data_cleaned['Topic'] == "Frequent mental distress"]
binge_drinking_data = data_cleaned[data_cleaned['Topic'] == "Binge drinking within past 30 days"]

correlation_by_state = {}
for state in data_cleaned['LocationAbbr'].unique():
    mental_distress_state = mental_distress_data[mental_distress_data['LocationAbbr'] == state]
    binge_drinking_state = binge_drinking_data[binge_drinking_data['LocationAbbr'] == state]
    if len(mental_distress_state) > 1 and len(binge_drinking_state) > 1:
        # Merging the datasets on common columns
        merged_data_state = pd.merge(mental_distress_state, binge_drinking_state, on=['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Stratification2'])
        if not merged_data_state.empty:
            correlation_state = merged_data_state[['Data_Value_x', 'Data_Value_y']].corr().iloc[0, 1]
            correlation_by_state[state] = correlation_state
        else:
            correlation_by_state[state] = 'Insufficient data'
    else:
        correlation_by_state[state] = 'Insufficient data'

sorted_data = sorted([(state, val) for state, val in correlation_by_state.items() if val != 'Insufficient data'], key=lambda x: x[1])
sorted_data += [(state, None) for state, val in correlation_by_state.items() if val == 'Insufficient data']
sorted_states = [item[0] for item in sorted_data]
sorted_correlation_values = [item[1] for item in sorted_data]
# Out:
#                                     RowId_x  YearStart  YearEnd LocationAbbr  \
# 0  BRFSS~2015~2015~37~Q03~TMC01~AGE~OVERALL       2015     2015           NC
# 1  BRFSS~2015~2015~37~Q03~TMC01~AGE~OVERALL       2015     2015           NC
# 2  BRFSS~2015~2015~37~Q03~TMC01~AGE~OVERALL       2015     2015           NC
# 3  BRFSS~2015~2015~37~Q03~TMC01~AGE~OVERALL       2015     2015           NC
# 4  BRFSS~2015~2015~37~Q03~TMC01~AGE~OVERALL       2015     2015           NC
#
#      LocationDesc Datasource_x        Class_x                   Topic_x  \
# 0  North Carolina        BRFSS  Mental Health  Frequent mental distress
# 1  North Carolina        BRFSS  Mental Health  Frequent mental distress
# 2  North Carolina        BRFSS  Mental Health  Frequent mental distress
# 3  North Carolina        BRFSS  Mental Health  Frequent mental distress
# 4  North Carolina        BRFSS  Mental Health  Frequent mental distress
#
#                                                                  Question_x  \
# 0  Percentage of older adults who are experiencing frequent mental distress
# 1  Percentage of older adults who are experiencing frequent mental distress
# 2  Percentage of older adults who are experiencing frequent mental distress
# 3  Percentage of older adults who are experiencing frequent mental distress
# 4  Percentage of older adults who are experiencing frequent mental distress
#
#   Data_Value_Unit_x DataValueTypeID_x Data_Value_Type_x  Data_Value_x  \
# 0                 %             PRCTG        Percentage          11.1
# 1                 %             PRCTG        Percentage          11.1
# 2                 %             PRCTG        Percentage          11.1
# 3                 %             PRCTG        Percentage          12.9
# 4                 %             PRCTG        Percentage          12.9
#
#    Data_Value_Alt_x  Low_Confidence_Limit_x  High_Confidence_Limit_x  \
# 0              11.1                     9.9                     12.5
# 1              11.1                     9.9                     12.5
# 2              11.1                     9.9                     12.5
# 3              12.9                    11.2                     14.8
# 4              12.9                    11.2                     14.8
#
#   StratificationCategory1_x Stratification1_x StratificationCategory2_x  \
# 0                 Age Group           Overall                       nan
# 1                 Age Group           Overall                       nan
# 2                 Age Group           Overall                       nan
# 3                 Age Group       50-64 years                       nan
# 4                 Age Group       50-64 years                       nan
#
#   Stratification2 ClassID_x TopicID_x QuestionID_x  LocationID_x  \
# 0             nan       C05     TMC01          Q03            37
# 1             nan       C05     TMC01          Q03            37
# 2             nan       C05     TMC01          Q03            37
# 3             nan       C05     TMC01          Q03            37
# 4             nan       C05     TMC01          Q03            37
#
#   StratificationCategoryID1_x StratificationID1_x StratificationCategoryID2_x  \
# 0                         AGE         AGE_OVERALL                     OVERALL
# 1                         AGE         AGE_OVERALL                     OVERALL
# 2                         AGE         AGE_OVERALL                     OVERALL
# 3                         AGE                5064                     OVERALL
# 4                         AGE                5064                     OVERALL
#
#   StratificationID2_x                                   RowId_y Datasource_y  \
# 0             OVERALL  BRFSS~2015~2015~37~Q21~TAC03~AGE~OVERALL        BRFSS
# 1             OVERALL  BRFSS~2015~2015~37~Q21~TAC03~AGE~OVERALL        BRFSS
# 2             OVERALL  BRFSS~2015~2015~37~Q21~TAC03~AGE~OVERALL        BRFSS
# 3             OVERALL  BRFSS~2015~2015~37~Q21~TAC03~AGE~OVERALL        BRFSS
# 4             OVERALL  BRFSS~2015~2015~37~Q21~TAC03~AGE~OVERALL        BRFSS
#
#                    Class_y                             Topic_y  \
# 0  Smoking and Alcohol Use  Binge drinking within past 30 days
# 1  Smoking and Alcohol Use  Binge drinking within past 30 days
# 2  Smoking and Alcohol Use  Binge drinking within past 30 days
# 3  Smoking and Alcohol Use  Binge drinking within past 30 days
# 4  Smoking and Alcohol Use  Binge drinking within past 30 days
#
#                                                                        Question_y  \
# 0  Percentage of older adults who reported binge drinking within the past 30 days
# 1  Percentage of older adults who reported binge drinking within the past 30 days
# 2  Percentage of older adults who reported binge drinking within the past 30 days
# 3  Percentage of older adults who reported binge drinking within the past 30 days
# 4  Percentage of older adults who reported binge drinking within the past 30 days
#
#   Data_Value_Unit_y DataValueTypeID_y Data_Value_Type_y  Data_Value_y  \
# 0                 %             PRCTG        Percentage           3.8
# 1                 %             PRCTG        Percentage           7.7
# 2                 %             PRCTG        Percentage          10.8
# 3                 %             PRCTG        Percentage           3.8
# 4                 %             PRCTG        Percentage           7.7
#
#    Data_Value_Alt_y  Low_Confidence_Limit_y  High_Confidence_Limit_y  \
# 0               3.8                     2.9                      4.9
# 1               7.7                     6.7                      8.8
# 2              10.8                     9.2                     12.6
# 3               3.8                     2.9                      4.9
# 4               7.7                     6.7                      8.8
#
#   StratificationCategory1_y  Stratification1_y StratificationCategory2_y  \
# 0                 Age Group  65 years or older                       nan
# 1                 Age Group            Overall                       nan
# 2                 Age Group        50-64 years                       nan
# 3                 Age Group  65 years or older                       nan
# 4                 Age Group            Overall                       nan
#
#   ClassID_y TopicID_y QuestionID_y  LocationID_y StratificationCategoryID1_y  \
# 0       C04     TAC03          Q21            37                         AGE
# 1       C04     TAC03          Q21            37                         AGE
# 2       C04     TAC03          Q21            37                         AGE
# 3       C04     TAC03          Q21            37                         AGE
# 4       C04     TAC03          Q21            37                         AGE
#
#   StratificationID1_y StratificationCategoryID2_y StratificationID2_y
# 0              65PLUS                     OVERALL             OVERALL
# 1         AGE_OVERALL                     OVERALL             OVERALL
# 2                5064                     OVERALL             OVERALL
# 3              65PLUS                     OVERALL             OVERALL
# 4         AGE_OVERALL                     OVERALL             OVERALL

# %%
colors = plt.cm.viridis(np.linspace(0, 1, len(sorted_states)))

plt.figure(figsize=(15, 8))
bars = plt.bar(sorted_states, sorted_correlation_values, color=colors)

for bar, value in zip(bars, sorted_correlation_values):
    y_val = bar.get_height()
    if value is None:
        bar.set_alpha(0.5)
        plt.text(bar.get_x() + bar.get_width() / 2, y_val, 'Insufficient data', ha='center', va='bottom', rotation=90, color='red')
    else:
        plt.text(bar.get_x() + bar.get_width() / 2, y_val, f'{value:.2f}', ha='center', va='bottom', rotation=90, color='black')

plt.title('Sorted Correlation Between Frequent Mental Distress and Binge Drinking by State')
plt.xlabel('State')
plt.ylabel('Correlation Coefficient')
plt.xticks(rotation=90)
plt.show()

# %%
sns.set(style="whitegrid")

data_subset = data_cleaned.sample(n=5000, random_state=1)
# data_subset_geo = data_cleaned

# Plot 1: Distribution of 'Data_Value' (after handling missing values)
plt.figure(figsize=(10, 6))
sns.histplot(data_subset['Data_Value'], kde=True)
plt.title('Distribution of Data Value')
plt.xlabel('Data Value')
plt.ylabel('Frequency')
plt.show()

# Plot 2: Yearly Distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='YearStart', data=data_subset)
plt.title('Yearly Distribution of Data')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# Plot 3: Top 10 Locations by Data Count
top_locations = data_subset['LocationDesc'].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_locations.values, y=top_locations.index)
plt.title('Top 10 Locations by Data Count')
plt.xlabel('Count')
plt.ylabel('Location')
plt.show()

# Plot 4: Boxplot of Data Value by Year
plt.figure(figsize=(10, 6))
sns.boxplot(x='YearStart', y='Data_Value', data=data_subset)
plt.title('Data Value by Year')
plt.xlabel('Year')
plt.ylabel('Data Value')
plt.show()

# gdf = gpd.GeoDataFrame(data_subset_geo, geometry=gpd.points_from_xy(data_subset_geo.Longitude, data_subset_geo.Latitude))
# world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# fig, ax = plt.subplots(figsize=(15, 10))
# world.plot(ax=ax, color='lightgrey')
# gdf.plot(ax=ax, color='blue', markersize=5)
# plt.show()
# Out:
# c:\Users\sbart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\sbart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\sbart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\sbart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\sbart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\sbart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\sbart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\sbart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\sbart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\sbart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\sbart\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## E2 - Exploratory data analysis (EDA)
# Use the clean dataset and to understand and explore the relationships in the data (numerical, visual, statistical). This includes at least but is not limited to:
# - A comprehensive textual description of meaning for relevant fields in the dataset
# - Statistical/numerical descriptions and visualization techniques we learned in the course inluding correlations, distributions and groupings of variing degrees.
# - Checks for data quality, e. g., completeness, plausibility, outliers
# - Handling any identified problems with the data
# - If necessary, use additional data wrangling in line with your EDA and only keep what's necessary for the following steps of your analysis with appropriate data granularity and form ("tidy data")
#
# Don't:
# - test/prove hypotheses here. EDA should only motivate hypotheses.
#
# Advanced/bonus:
# - Depending on your hypothesis you may want to join external data (e.g., merge external highest education level to existing vaccination data) for additional insights.
#
# Explain all steps taken and your thinking why you deem them necessary.

# %%
# E2:

# %% [markdown]
# ## E3 - Formulate hypotheses
#
# *Note: Read this section entirely and understand it - every group member.*
#
# A hypothesis is an idea or explanation for something that is based on known facts but has not yet been proved. A hypothesis is a compact, concise statement, such as: "Individuals with higher income have (on average) more offspring.", that will be answered based on facts (the data). https://gradcoach.com/what-is-a-research-hypothesis-or-scientific-hypothesis/
#
# Formulate 5 non-trivial hypotheses, 1 per group member, and regard the following criteria:
# - State the hypothesis explicitly in concise language.
# - The hypothesis must be **motivated** by either **EDA results** or **literature** (citation in the report needed).
# - The hypothesis must refer to **endpoints** that are **testable**. Specifically, the endpoint must be derived from the data.
# - Think of real-life use cases/consequences of your results (textual description).
# - For each hypothesis explain all executed steps.
# - In case of extreme or implausible results check the validity of your data.
# - For each hypothesis export the artifacts (figures, tables, etc.) required for the report.
# - If you decide to use a statistical test, use it properly. In particular, check the validity and comparability of the samples.
#
# Do not:
# - State nebulous, vague hypotheses. These don't contain endpoints and are unclear to test (i.e., answer).
# - Use post-hoc hypotheses. Portraying an empirically inspired **post hoc hypothesis as a priori** violates the **falsification principle** crucial for hypothesis-driven (that is, confirmatory) empirical research. Falsification is severe scientific fraud.
# - State trivial hypotheses (e.g., hypthesis 2: "Not Hypothesis 1").
# - Answer based on "common knowledge".
# - Try to **produce positively tested hypotheses**. If a well motivated hypothesis is negative, this is an important finding (see Simpson's Paradox). The value of a tested hypothesis lies in the information or learning it provides.
#
# Example: The homework with Simpson's Paradox. The pooled overall comparison between the genders would be the EDA motivating the hypothesis: "At UC Berkeley the by-department admissions rate for females is lower than for males." It should be tested using samples of department admission rates for the 2 **groups** male and female. No steps of the test should be done in EDA (or a priory to stating the hypothesis). The groups should be compared graphically, e.g., via a stripplot overlayed with a boxplot. The figure should be labelled properly and exported for the report. A (paired) t-test *may* be used to test this hypothesis statistically. For different data (e.g., time series) different approaches may be required.

# %% [markdown]
# ### E3-H1: "xxx"
# Author: Group member 1

# %% [markdown]
# ### E3-H2: "People among the study; which taking blood medications tend to have arthritis"
# Author: Group member 2 - Stefan Bartl

# %% [markdown]
# In the first step, the neccesary data need to be filtered. In case of this hypothesis, we need top extract two dataframes. On the one hand we have the arthritis data, and on the other the blood pressure medication. Both variables which needs to be observed (`Data_Value`) are in percentage. To get a first impression of the data, a 5-point analysis is made.

# %%
arthritis_data = data_cleaned[(data_cleaned["Topic"] == "Arthritis among older adults") & (data_cleaned["Question"] == 'Percentage of older adults ever told they have arthritis')]
blood_medication_data = data_cleaned[data_cleaned["Topic"] == "Taking medication for high blood pressure"]
pd.DataFrame({"Arthritis": arthritis_data["Data_Value"].describe(), "Blood Med":blood_medication_data["Data_Value"].describe()})
# Out:
#          Arthritis    Blood Med
# count  5015.000000  3727.000000
# mean     41.897368    87.457124
# std       9.677711     5.713117
# min       9.500000    63.600000
# 25%      35.100000    84.000000
# 50%      42.100000    88.400000
# 75%      49.000000    91.900000
# max      76.300000    99.600000

# %% [markdown]
# To get a first glimpes of the data, a histogram is displayed. The distribution of arthritis seems to be like normailzed (gausian bell curve). Blood medication data has a very slight rightward steepness.

# %%
plt.figure(figsize=(10, 6))

sns.histplot(arthritis_data["Data_Value"], kde=True, label="Arthritis Data", color="blue", alpha=0.7)
sns.histplot(blood_medication_data["Data_Value"], kde=True, label="Blood Medication Data", color="orange", alpha=0.7)
plt.legend()

plt.xlabel("Data Value in %")
plt.ylabel("Frequency")
plt.title("Histograms of Arthritis and Blood Medication Data")

plt.show()

# %% [markdown]
# To see if there are any outliers, the visualization of a bloxplot is the best choice. As you can see in the following plot, we have no outliers in the dataset.

# %%
plt.figure(figsize=(12, 4))

plt.subplot(2, 1, 1)
sns.boxplot(
    data=arthritis_data, x="Data_Value",
    whis=[0, 100], width=.6, color="blue"
)
plt.title('Arthritis Data')
plt.xlabel('Arthritis %')

plt.subplot(2, 1, 2)
sns.boxplot(
    data=blood_medication_data, x="Data_Value",
    whis=[0, 100], width=.6, color="blue"
)
plt.title('Blood Medication Data')
plt.xlabel('Blood Medication %')

plt.tight_layout()
plt.show()

# %%
for state in data_cleaned['LocationAbbr'].unique():
    arthritis_state = arthritis_data[arthritis_data['LocationAbbr'] == state]
    blood_medication_state = blood_medication_data[blood_medication_data['LocationAbbr'] == state]
    if len(arthritis_state) > 1 and len(blood_medication_state) > 1:
        # Merging the datasets on common columns
        merged_data_state = pd.merge(arthritis_state, blood_medication_state, on=['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Stratification1','StratificationCategory1','StratificationCategory2','Stratification2'])
        correlation_state = merged_data_state[['Data_Value_x', 'Data_Value_y']].corr().iloc[0, 1]
    
sns.scatterplot(data=merged_data_state, x="Data_Value_x", y="Data_Value_y")
sns.regplot(data=merged_data_state, x="Data_Value_x", y="Data_Value_y", scatter=False)  # scatter=False to remove duplicate points


plt.xlabel("Arthritis %")
plt.ylabel("blood pressure medication %")

plt.show()

# %% [markdown]
# ### E3-H3: "xxx"
# Author: Group member 3

# %% [markdown]
# ### E3-H4: "xxx"
# Author: Group member 4

# %% [markdown]
# ### E3-H5: "xxx"
# Author: Group member 5
